# %%
import pandas as pd

# %%
df = pd.read_csv("./공원(1인당+공원면적)_20240610135552.csv", skiprows=[0,1])
df1 = df[['자치구별(2)', '1인당 공원면적 (㎡).2']]
df2 = df1.iloc[1:26]
df3 = df2.rename(columns={'자치구별(2)': '구', '1인당 공원면적 (㎡).2': '1인당 공원면적'})
df3
# Out:
#        구 1인당 공원면적
# 1    종로구    19.85
# 2     중구    10.63
# 3    용산구     6.91
# 4    성동구    10.08
# 5    광진구     3.85
# 6   동대문구     2.97
# 7    중랑구     4.83
# 8    성북구     3.80
# 9    강북구     6.90
# 10   도봉구     3.57
# 11   노원구     3.73
# 12   은평구     4.71
# 13  서대문구     3.52
# 14   마포구    11.57
# 15   양천구     4.97
# 16   강서구     6.14
# 17   구로구     3.96
# 18   금천구     2.32
# 19  영등포구     7.43
# 20   동작구     5.94
# 21   관악구     3.93
# 22   서초구     5.42
# 23   강남구     6.85
# 24   송파구     6.58
# 25   강동구     4.58

# %%
df3.to_csv("./환경1_도보생활권공원면적.csv", index=False, encoding='utf-8-sig')
